# %%
import sys
print(sys.executable)
# Out:
# /scratch.global/inoue019/conda-envs/myenv/bin/python

# %%
# !{sys.executable} -m pip install tqdm pubchempy pandas numpy scipy scikit-learn seaborn rdkit
# Out:
# Requirement already satisfied: tqdm in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: pubchempy in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (1.0.4)
# Requirement already satisfied: pandas in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: scipy in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (1.15.2)
# Requirement already satisfied: scikit-learn in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: seaborn in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (0.13.2)
# Collecting rdkit
#   Downloading rdkit-2024.9.6-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: Pillow in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from rdkit) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: six>=1.5 in /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading rdkit-2024.9.6-cp310-cp310-manylinux_2_28_x86_64.whl (34.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 28.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: rdkit
# Successfully installed rdkit-2024.9.6

# %%
import argparse

from tqdm import tqdm

# %%
# %load_ext autoreload
# %autoreload 2

from load_data import load_data
from model import Optimizer, nihgcn
from myutils import *
from sampler import NewSampler
from sklearn.model_selection import KFold
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class Args:
    def __init__(self):
        self.device = torch.device(
            "cuda" if torch.cuda.is_available() else "cpu"
        )  # cuda:number or cpu
        self.data = "ctrp"  # Dataset{gdsc or ccle}
        self.lr = 0.001  # the learning rate
        self.wd = 1e-5  # the weight decay for l2 normalizaton
        self.layer_size = [1024, 1024]  # Output sizes of every layer
        self.alpha = 0.25  # the scale for balance gcn and ni
        self.gamma = 8  # the scale for sigmod
        self.epochs = 1000  # the epochs for model


args = Args()

# %%
res, drug_finger, exprs, null_mask, pos_num = load_data(args)
cell_sum = np.sum(res, axis=1)
drug_sum = np.sum(res, axis=0)

target_dim = [
    0,  # Cell
    # 1  # Drug
]

# %%
def nihgcn_new(
    cell_exprs,
    drug_finger,
    res_mat,
    null_mask,
    target_dim,
    target_index,
    evaluate_fun,
    args,
    seed,
):

    sampler = NewSampler(res_mat, null_mask, target_dim, target_index, seed)

    val_labels = sampler.test_data[sampler.test_mask]

    if len(np.unique(val_labels)) < 2:
        print(f"Target {target_index} skipped: Validation set has only one class.")
        return None, None

    model = nihgcn(
        sampler.train_data,
        cell_exprs=cell_exprs,
        drug_finger=drug_finger,
        layer_size=args.layer_size,
        alpha=args.alpha,
        gamma=args.gamma,
        device=args.device,
    )
    opt = Optimizer(
        model,
        sampler.train_data,
        sampler.test_data,
        sampler.test_mask,
        sampler.train_mask,
        evaluate_fun,
        lr=args.lr,
        wd=args.wd,
        epochs=args.epochs,
        device=args.device,
    )
    true_data, predict_data = opt()
    return true_data, predict_data

# %%
from joblib import Parallel, delayed
from tqdm import tqdm

n_kfold = 1
n_jobs = 50  # 並列数


def process_iteration(dim, target_index, seed, args):
    """各反復処理をカプセル化した関数"""
    if dim:
        if drug_sum[target_index] < 10:
            return None, None
    else:
        if cell_sum[target_index] < 10:
            return None, None

    fold_results = []
    for fold in range(n_kfold):
        true_data, predict_data = nihgcn_new(
            cell_exprs=exprs,
            drug_finger=drug_finger,
            res_mat=res,
            null_mask=null_mask,
            target_dim=dim,
            target_index=target_index,
            evaluate_fun=roc_auc,
            args=args,
            seed=seed,
        )
        fold_results.append((true_data, predict_data))

    return fold_results


# 並列処理の実行
true_data_s = pd.DataFrame()
predict_data_s = pd.DataFrame()

for dim in target_dim:
    # 全タスクを事前に生成
    tasks = [
        (dim, target_index, seed, args)
        for seed, target_index in enumerate(np.arange(res.shape[dim]))
    ]

    # 並列実行（プログレスバー付き）
    results = Parallel(n_jobs=n_jobs, verbose=0, prefer="threads")(
        delayed(process_iteration)(*task)
        for task in tqdm(tasks, desc=f"Processing dim {dim}")
    )

    # 結果の結合
    for fold_results in results:
        if fold_results is None:
            continue
        for true_data, predict_data in fold_results:
            true_data_s = pd.concat(
                [true_data_s, translate_result(true_data)],
                ignore_index=True,
                copy=False,  # メモリ節約のため
            )
            predict_data_s = pd.concat(
                [predict_data_s, translate_result(predict_data)],
                ignore_index=True,
                copy=False,
            )
# Out:
# Processing dim 0:   0%|          | 0/823 [00:00<?, ?it/s]
# epoch:   0 loss:0.699953 auc:0.5388
# epoch:   0 loss:0.698458 auc:0.4644
# epoch:   0 loss:0.703540 auc:0.4805
# epoch:   0 loss:0.698881 auc:0.5223
# epoch:   0 loss:0.697864 auc:0.4389
# epoch:   0 loss:0.700997 auc:0.5237
# epoch:   0 loss:0.705132 auc:0.5138
# epoch:   0 loss:0.703500 auc:0.4763
# epoch:   0 loss:0.700175 auc:0.4216
# epoch:   0 loss:0.700983 auc:0.4707
# epoch:   0 loss:0.698952 auc:0.5197
# epoch:   0 loss:0.702697 auc:0.5402
# epoch:   0 loss:0.700577 auc:0.5648
# epoch:   0 loss:0.701639 auc:0.5107
# epoch:   0 loss:0.701718 auc:0.4957
# epoch:   0 loss:0.700503 auc:0.4840
# epoch:   0 loss:0.699038 auc:0.5136
# epoch:   0 loss:0.704676 auc:0.4763
# epoch:   0 loss:0.698996 auc:0.4397
# epoch:   0 loss:0.702801 auc:0.4713
# epoch:   0 loss:0.697613 auc:0.4685
# epoch:   0 loss:0.701576 auc:0.5237
# epoch:   0 loss:0.698256 auc:0.5406
# epoch:   0 loss:0.701663 auc:0.5272
# epoch:   0 loss:0.698616 auc:0.5434
# epoch:   0 loss:0.700015 auc:0.4764
# epoch:   0 loss:0.700123 auc:0.4070
# epoch:   0 loss:0.703257 auc:0.4199
# epoch:   0 loss:0.699492 auc:0.5647
# epoch:   0 loss:0.699675 auc:0.5428
# epoch:   0 loss:0.702328 auc:0.5056
# epoch:   0 loss:0.700940 auc:0.4980
# epoch:   0 loss:0.698242 auc:0.5512
# epoch:   0 loss:0.700545 auc:0.4647
# epoch:   0 loss:0.697381 auc:0.5303
# epoch:   0 loss:0.699326 auc:0.4774
# epoch:   0 loss:0.701634 auc:0.5182
# epoch:   0 loss:0.699276 auc:0.5418
# epoch:   0 loss:0.699136 auc:0.4712
# epoch:   0 loss:0.700260 auc:0.5085
# epoch:   0 loss:0.698342 auc:0.4335
# epoch:   0 loss:0.697431 auc:0.4828
# epoch:   0 loss:0.700333 auc:0.5241
# epoch:   0 loss:0.699357 auc:0.5181
# epoch:   0 loss:0.703799 auc:0.5039
# epoch:   0 loss:0.699839 auc:0.4966
# epoch:   0 loss:0.697626 auc:0.4510
# epoch:   0 loss:0.699588 auc:0.4943
# epoch:   0 loss:0.701793 auc:0.4616
# epoch:   0 loss:0.702097 auc:0.5445
# epoch:  20 loss:0.352494 auc:0.9094
# epoch:  20 loss:0.350886 auc:0.8890
# epoch:  20 loss:0.355164 auc:0.8500
# epoch:  40 loss:0.329700 auc:0.9087
# epoch:  40 loss:0.325825 auc:0.8950
# epoch:  40 loss:0.329357 auc:0.8530
# epoch:  60 loss:0.304972 auc:0.9066
# epoch:  60 loss:0.306413 auc:0.8559
# epoch:  60 loss:0.304785 auc:0.8948
# epoch:  80 loss:0.282399 auc:0.9083
# epoch:  80 loss:0.287196 auc:0.8552
# epoch:  80 loss:0.278514 auc:0.8951
# epoch:  20 loss:0.353182 auc:0.9310
# epoch:  20 loss:0.352411 auc:0.9161
# epoch:  20 loss:0.353376 auc:0.9324
# epoch:  20 loss:0.353044 auc:0.9461
# epoch:  20 loss:0.353534 auc:0.9502
# epoch:  20 loss:0.351970 auc:0.9136
# epoch:  20 loss:0.353343 auc:0.9625
# epoch:  20 loss:0.352250 auc:0.9434
# epoch:  20 loss:0.352183 auc:0.9549
# epoch:  20 loss:0.356436 auc:0.9134
# epoch:  20 loss:0.354102 auc:0.9340
# epoch:  20 loss:0.352764 auc:0.9431
# epoch:  20 loss:0.353678 auc:0.9029
# epoch:  20 loss:0.350935 auc:0.9403
# epoch: 100 loss:0.262208 auc:0.9078
# epoch:  20 loss:0.351015 auc:0.9251
# epoch: 100 loss:0.264228 auc:0.8537
# epoch: 100 loss:0.259662 auc:0.8937
# epoch:  40 loss:0.327096 auc:0.9637
# epoch:  40 loss:0.330519 auc:0.9289
# epoch: 120 loss:0.250418 auc:0.9062
# epoch: 120 loss:0.250916 auc:0.8510
# epoch: 120 loss:0.249271 auc:0.8891
# epoch:  40 loss:0.329743 auc:0.9368
# epoch:  40 loss:0.329677 auc:0.9658
# epoch:  40 loss:0.328353 auc:0.9492
# epoch:  40 loss:0.327066 auc:0.9460
# epoch:  40 loss:0.326080 auc:0.9456
# epoch:  40 loss:0.330071 auc:0.9097
# epoch:  40 loss:0.327797 auc:0.9204
# epoch:  40 loss:0.329905 auc:0.9152
# epoch:  40 loss:0.331414 auc:0.9497
# epoch:  60 loss:0.304315 auc:0.9620
# epoch: 140 loss:0.243027 auc:0.9086
# epoch:  60 loss:0.308062 auc:0.9365
# epoch: 140 loss:0.242269 auc:0.8486
# epoch: 140 loss:0.240817 auc:0.8879
# epoch:  60 loss:0.305872 auc:0.9563
# epoch:  60 loss:0.307724 auc:0.9666
# epoch:  60 loss:0.305789 auc:0.9389
# epoch:  40 loss:0.326923 auc:0.9225
# epoch:  80 loss:0.281297 auc:0.9602
# epoch:  60 loss:0.303708 auc:0.9456
# epoch:  60 loss:0.308000 auc:0.9088
# epoch:  60 loss:0.301791 auc:0.9491
# epoch: 160 loss:0.236121 auc:0.9041
# epoch:  80 loss:0.283535 auc:0.9403
# epoch: 160 loss:0.237119 auc:0.8492
# epoch:  40 loss:0.332465 auc:0.9126
# epoch:  40 loss:0.327093 auc:0.9464
# epoch: 160 loss:0.236049 auc:0.8834
# epoch:  20 loss:0.352497 auc:0.9279
# epoch:  20 loss:0.352497 auc:0.9497
# epoch:  20 loss:0.349618 auc:0.6815
# epoch:  20 loss:0.352860 auc:0.9409
# epoch:  20 loss:0.352305 auc:0.9386
# epoch:  20 loss:0.350963 auc:0.9187
# epoch:  20 loss:0.354553 auc:0.9162
# epoch:  20 loss:0.351542 auc:0.9281
# epoch:  20 loss:0.351883 auc:0.9387
# epoch:  20 loss:0.349785 auc:0.9057
# epoch:  20 loss:0.351895 auc:0.8790
# epoch:  20 loss:0.351797 auc:0.9279
# epoch:  20 loss:0.350548 auc:0.9306
# epoch:  20 loss:0.353382 auc:0.9386
# epoch:  80 loss:0.281169 auc:0.9580
# epoch: 180 loss:0.234094 auc:0.9041
# epoch: 100 loss:0.263074 auc:0.9597
# epoch: 180 loss:0.232450 auc:0.8492
# epoch: 100 loss:0.263723 auc:0.9409
# epoch:  80 loss:0.285586 auc:0.9570
# epoch:  80 loss:0.281354 auc:0.9421
# epoch: 180 loss:0.231825 auc:0.8884
# epoch:  60 loss:0.304338 auc:0.9157
# epoch:  60 loss:0.307004 auc:0.8918
# epoch:  60 loss:0.307217 auc:0.9506
# epoch:  80 loss:0.280034 auc:0.9446
# epoch:  80 loss:0.286143 auc:0.9064
# epoch:  80 loss:0.277243 auc:0.9458
# epoch: 200 loss:0.229419 auc:0.9029
# epoch: 120 loss:0.249721 auc:0.9612
# epoch: 100 loss:0.270892 auc:0.9548
# epoch: 200 loss:0.231981 auc:0.8527
# epoch: 200 loss:0.228873 auc:0.8906
# epoch: 120 loss:0.258647 auc:0.9381
# epoch: 100 loss:0.263248 auc:0.9414
# epoch: 100 loss:0.263225 auc:0.9590
# epoch: 220 loss:0.226848 auc:0.9020
# epoch: 140 loss:0.241111 auc:0.9614
# epoch: 220 loss:0.227599 auc:0.8491
# epoch: 220 loss:0.227869 auc:0.8923
# epoch: 120 loss:0.251365 auc:0.9588
# epoch: 140 loss:0.243001 auc:0.9410
# epoch: 240 loss:0.225927 auc:0.8985
# epoch: 100 loss:0.260951 auc:0.9406
# epoch: 100 loss:0.265006 auc:0.9044
# epoch: 100 loss:0.260766 auc:0.9427
# epoch: 120 loss:0.250510 auc:0.9390
# epoch:  80 loss:0.280089 auc:0.9252
# epoch: 240 loss:0.225973 auc:0.8514
# epoch: 160 loss:0.238158 auc:0.9603
# epoch: 120 loss:0.250901 auc:0.9568
# epoch:  80 loss:0.283155 auc:0.8744
# epoch:  80 loss:0.283668 auc:0.9556
# epoch: 240 loss:0.224916 auc:0.8945
# epoch: 160 loss:0.236849 auc:0.9398
# epoch: 140 loss:0.242080 auc:0.9603
# epoch:  60 loss:0.302212 auc:0.9222
# epoch: 260 loss:0.223991 auc:0.9033
# epoch: 260 loss:0.226638 auc:0.8540
# epoch: 140 loss:0.241754 auc:0.9362
# epoch: 180 loss:0.231853 auc:0.9599
# epoch: 260 loss:0.229794 auc:0.8784
# epoch: 140 loss:0.242114 auc:0.9539
# epoch: 180 loss:0.233633 auc:0.9388
# epoch: 160 loss:0.236507 auc:0.9577
# epoch: 280 loss:0.224019 auc:0.9033
# epoch: 120 loss:0.251040 auc:0.9403
# epoch: 120 loss:0.254554 auc:0.9019
# epoch: 120 loss:0.247817 auc:0.9426
# epoch: 280 loss:0.222866 auc:0.8500
# epoch: 200 loss:0.231855 auc:0.9578
# epoch: 280 loss:0.222889 auc:0.9018
# epoch: 300 loss:0.221549 auc:0.9001
# epoch: 160 loss:0.237631 auc:0.9350
# epoch: 200 loss:0.230280 auc:0.9374
# epoch: 300 loss:0.222920 auc:0.8485
# epoch: 180 loss:0.232912 auc:0.9620
# epoch: 220epoch: 160 loss:0.236716 auc:0.9552
#  loss:0.227204 auc:0.9589
# epoch: 300 loss:0.221242 auc:0.9004
# epoch: 320 loss:0.221227 auc:0.8999
# epoch: 320 loss:0.221350 auc:0.8430
# epoch: 100 loss:0.261648 auc:0.9280
# epoch: 220 loss:0.227660 auc:0.9365
# epoch: 320 loss:0.221684 auc:0.8994
# epoch: 340 loss:0.220089 auc:0.9054
# epoch: 240 loss:0.225022 auc:0.9587
# epoch: 140 loss:0.241510 auc:0.9397
# epoch: 200 loss:0.229363 auc:0.9614
# epoch: 180 loss:0.232253 auc:0.9348
# epoch: 340 loss:0.220198 auc:0.8462
# epoch: 140 loss:0.244188 auc:0.9410
# epoch: 140 loss:0.243225 auc:0.9025
# epoch: 180 loss:0.244117 auc:0.9422
# epoch: 360 loss:0.219460 auc:0.9027
# epoch: 340 loss:0.220744 auc:0.8907
# epoch: 240 loss:0.226195 auc:0.9363
# epoch: 260 loss:0.225198 auc:0.9589
# epoch: 220 loss:0.227782 auc:0.9611
# epoch: 360 loss:0.223556 auc:0.8338
# epoch: 200 loss:0.239321 auc:0.9296
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 47
#      41 tasks = [
#      42     (dim, target_index, seed, args)
#      43     for seed, target_index in enumerate(np.arange(res.shape[dim]))
#      44 ]
#      46 # 並列実行（プログレスバー付き）
# ---> 47 results = Parallel(n_jobs=n_jobs, verbose=0, prefer="threads")(
#      48     delayed(process_iteration)(*task)
#      49     for task in tqdm(tasks, desc=f"Processing dim {dim}")
#      50 )
#      52 # 結果の結合
#      53 for fold_results in results:
#
# File /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /scratch.global/inoue019/conda-envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
# epoch: 380 loss:0.222023 auc:0.8977
# epoch: 360 loss:0.219016 auc:0.8916
# epoch: 260 loss:0.226092 auc:0.9317
# epoch: 280 loss:0.223057 auc:0.9581
# epoch: 380 loss:0.218728 auc:0.8449
# epoch: 160 loss:0.237393 auc:0.9408
# epoch: 200 loss:0.231040 auc:0.9545
# epoch: 240 loss:0.225650 auc:0.9627
# epoch: 100 loss:0.264644 auc:0.9531
# epoch: 400 loss:0.217976 auc:0.8980
# epoch:  40 loss:0.326110 auc:0.9213
# epoch: 380 loss:0.218726 auc:0.8975

# %%
true_data_s.to_csv(f"new_cell_true_{args.data}.csv")
predict_data_s.to_csv(f"new_cell_pred_{args.data}.csv")
