# %%
import argparse
import os
import random
import time
import warnings

import numpy as np
import pandas as pd
import torch
import torch.utils.data as Data
from molFrags import *
from sklearn.model_selection import KFold
from torch_dataset import *
from tqdm import tqdm

warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2

from data_process import data_process
from load_data import load_data
from main_classify import *
from MF import *
from models_classify import *
from sampler import NewSampler
from utils import *

# %%
tmp = "gdsc2"

class Args:
    def __init__(self):
        self.lr = 0.0001  # 学習率
        self.bs = 5000  # バッチサイズ
        self.ep = 100  # エポック数
        self.o = f"./{tmp}_output_dir/"  # 出力ディレクトリ
        self.data = tmp


# argsオブジェクトを作成
args = Args()

# %%
os.makedirs(args.o, exist_ok=True)
# ---data process
start_time = time.time()
seed = 42
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

drug_subfeat, cline_subfeat, drug_dim, drug_compo_elem, cline_compos_elem = (
    data_process(args)
)
# Out:
# Loading data files...
# Processing drug data...
# 1005it [00:05, 175.83it/s]
# Drug processing complete.
# Processing cell line data...
# Cell line processing complete.

# %%
def prepare_matrix_factorization(train_set):
    """Matrix factorization preparation and execution"""
    print("Building known matrix...")
    CDR_known = train_set.set_index(["Cline", "Drug"]).unstack("Cline")
    CDR_known.columns = CDR_known.columns.droplevel()

    CDR_matrix = np.array(CDR_known)
    CDR_mask = 1 - np.float32(np.isnan(CDR_matrix))
    CDR_matrix[np.isnan(CDR_matrix)] = 0

    print("Performing matrix factorization...")
    drug_glofeat, cline_glofeat = svt_solve(A=CDR_matrix, mask=CDR_mask)
    drug_glofeat = pd.DataFrame(drug_glofeat, index=list(CDR_known.index))
    cline_glofeat = pd.DataFrame(cline_glofeat, index=list(CDR_known.columns))

    return drug_glofeat, cline_glofeat


def prepare_data_loaders(
    train_set, validation_set, drug_glofeat, cline_glofeat, batch_sizes
):
    """Prepare train and validation data loaders"""
    print("Preparing data loaders...")
    # Shuffle data
    train_set = train_set.sample(frac=1, random_state=seed)
    validation_set = validation_set.sample(frac=1, random_state=seed)

    # Create train loaders
    print("Preparing train data loaders...")
    drug_loader_train, cline_loader_train, glo_loader_train, _, _, label_train = (
        BatchGenerate(
            train_set,
            drug_subfeat,
            cline_subfeat,
            drug_glofeat,
            cline_glofeat,
            drug_compo_elem,
            cline_compos_elem,
            bs=batch_sizes,
        )
    )

    # Create validation loaders
    print("Preparing test data loaders...")
    (
        drug_loader_valid,
        cline_loader_valid,
        glo_loader_valid,
        dc_valid,
        cc_valid,
        label_valid,
    ) = BatchGenerate(
        validation_set,
        drug_subfeat,
        cline_subfeat,
        drug_glofeat,
        cline_glofeat,
        drug_compo_elem,
        cline_compos_elem,
        bs=batch_sizes,
    )

    return (
        drug_loader_train,
        cline_loader_train,
        glo_loader_train,
        label_train,
        drug_loader_valid,
        cline_loader_valid,
        glo_loader_valid,
        label_valid,
        dc_valid,
        cc_valid,
    )


def setup_model(drug_dim, glo_dim, device, args):
    """Initialize model and optimizer"""
    print("Initializing model and optimizer...")
    model = SubCDR(
        SubEncoder(in_drug=drug_dim, in_cline=8, out=82),
        GraphEncoder(in_channels=32, out_channels=16),
        GloEncoder(in_channels=glo_dim, out_channels=128),
        Decoder(in_channels=160),
    ).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, weight_decay=1e-4)
    myloss = torch.nn.BCELoss()

    return model, optimizer, myloss


def train_epoch(model, loaders, optimizer, myloss):
    """Train for one epoch"""
    model.train()
    drug_loader_train, cline_loader_train, glo_loader_train, label_train = loaders
    train(
        model,
        optimizer,
        myloss,
        drug_loader_train,
        cline_loader_train,
        glo_loader_train,
        label_train,
    )


def validate(model, loaders, myloss):
    """Perform validation"""
    drug_loader_valid, cline_loader_valid, glo_loader_valid, label_valid = loaders
    auc, aupr, y_true, y_pred = test(
        model,
        myloss,
        drug_loader_valid,
        cline_loader_valid,
        glo_loader_valid,
        label_valid,
    )
    return auc, aupr, y_true, y_pred


def train_and_validate_fold(train_set, validation_set, args):
    """Main training and validation function for one fold"""
    print(
        f"Train set size: {len(train_set)}, Validation set size: {len(validation_set)}"
    )

    # Matrix factorization
    drug_glofeat, cline_glofeat = prepare_matrix_factorization(train_set)
    glo_dim = 2 * drug_glofeat.shape[1]

    # Prepare data
    batch_sizes = args.bs
    loaders = prepare_data_loaders(
        train_set, validation_set, drug_glofeat, cline_glofeat, batch_sizes
    )
    train_loaders = loaders[:4]
    valid_loaders = loaders[4:8]

    # Setup model
    model, optimizer, myloss = setup_model(drug_dim, glo_dim, device, args)

    # Training loop
    print("\nStarting training...")
    start = time.time()
    best_auc = 0
    best_aupr = 0

    for epoch in range(args.ep):
        print(f"\nEpoch {epoch + 1}/{args.ep}")

        # Train
        print("Training...")
        train_epoch(model, train_loaders, optimizer, myloss)

        # Validate
        print("Validating...")
        auc, aupr, y_true, y_pred = validate(model, valid_loaders, myloss)
        print(f"Test AUC: {auc:.4f}, Test AUPR: {aupr:.4f}")

        # Save best model
        if auc > best_auc:
            print("New best model found! Saving...")
            best_auc = auc
            best_aupr = aupr
            best_pred = y_pred
            torch.save(model.state_dict(), f"{args.o}classification_model.pkl")

    training_time = time.time() - start
    print(f"Best AUC: {best_auc:.4f}, Best AUPR: {best_aupr:.4f}")
    return best_pred, y_true

# %%
res, exprs, null_mask, pos_num = load_data(args)
cells = {i: j for i, j in enumerate(res.index)}
drugs = {i: j for i, j in enumerate(res.columns)}
cell_sum = np.sum(res, axis=1)
drug_sum = np.sum(res, axis=0)

target_dim = [
    0,  # Cell
    # 1  # Drug
]
# Out:
# load nci

# %%
n_kfold = 1
true_data_s = pd.DataFrame()
predict_data_s = pd.DataFrame()
for dim in target_dim:
    for seed, target_index in enumerate(tqdm(np.arange(res.shape[dim]))):
        if dim:
            if drug_sum[target_index] < 10:
                continue
        else:
            if cell_sum[target_index] < 10:
                continue
        epochs = []
        for fold in range(n_kfold):
            sampler = NewSampler(res.values, null_mask.values, target_dim, target_index, seed)

            train_data = pd.DataFrame(
                sampler.train_data, index=res.index, columns=res.columns
            )
            test_data = pd.DataFrame(
                sampler.test_data, index=res.index, columns=res.columns
            )
    
            train_mask = pd.DataFrame(
                sampler.train_mask, index=res.index, columns=res.columns
            )
            test_mask = pd.DataFrame(
                sampler.test_mask, index=res.index, columns=res.columns
            )
    
            train = pd.DataFrame(train_mask.values.nonzero()).T
            train[2] = train_data.values[train_mask.values.nonzero()].astype(int)
    
            test = pd.DataFrame(test_mask.values.nonzero()).T
            test[2] = test_data.values[test_mask.values.nonzero()].astype(int)
    
            train[0] = [cells[i] for i in train[0]]
            train[1] = [drugs[i] for i in train[1]]
    
            test[0] = [cells[i] for i in test[0]]
            test[1] = [drugs[i] for i in test[1]]
    
            cols = ["Cline", "Drug", "Values"]
    
            train.columns = cols
            test.columns = cols
    
            train_set = train
            validation_set = test
            best_pred, y_true = train_and_validate_fold(train_set, validation_set, args)
                
            true_data_s = pd.concat(
                [true_data_s, pd.DataFrame(y_trues)], ignore_index=True
            )
            predict_data_s = pd.concat(
                [predict_data_s, pd.DataFrame(best_preds)], ignore_index=True
            )
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# Train set size: 57959, Validation set size: 60
# Building known matrix...
# Performing matrix factorization...
#   0%|          | 0/60 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 49
#      47 train_set = train
#      48 validation_set = test
# ---> 49 best_pred, y_true = train_and_validate_fold(train_set, validation_set, args)
#      51 true_data_s = pd.concat(
#      52     [true_data_s, pd.DataFrame(y_trues)], ignore_index=True
#      53 )
#      54 predict_data_s = pd.concat(
#      55     [predict_data_s, pd.DataFrame(best_preds)], ignore_index=True
#      56 )
#
# Cell In[6], line 129, in train_and_validate_fold(train_set, validation_set, args)
#     124 print(
#     125     f"Train set size: {len(train_set)}, Validation set size: {len(validation_set)}"
#     126 )
#     128 # Matrix factorization
# --> 129 drug_glofeat, cline_glofeat = prepare_matrix_factorization(train_set)
#     130 glo_dim = 2 * drug_glofeat.shape[1]
#     132 # Prepare data
#
# Cell In[6], line 12, in prepare_matrix_factorization(train_set)
#       9 CDR_matrix[np.isnan(CDR_matrix)] = 0
#      11 print("Performing matrix factorization...")
# ---> 12 drug_glofeat, cline_glofeat = svt_solve(A=CDR_matrix, mask=CDR_mask)
#      13 drug_glofeat = pd.DataFrame(drug_glofeat, index=list(CDR_known.index))
#      14 cline_glofeat = pd.DataFrame(cline_glofeat, index=list(CDR_known.columns))
#
# File ~/code/Benchmark/SubCDR/MF.py:92, in svt_solve(A, mask, tau, delta, epsilon, rel_improvement, max_iterations, algorithm)
#      89 if sk < 1:  # 次元数が0になるのを防止
#      90     sk = 1
# ---> 92 (U, S, V) = _my_svd(Y, sk, algorithm)
#      93 shrink_S = np.maximum(S - tau, 0)
#      94 r_previous = np.count_nonzero(shrink_S)
#
# File ~/code/Benchmark/SubCDR/MF.py:11, in _my_svd(M, k, algorithm)
#       9 def _my_svd(M, k, algorithm):
#      10     if algorithm == "randomized":
# ---> 11         (U, S, V) = randomized_svd(
#      12             M,
#      13             n_components=min(k, min(M.shape) - 1),  # より安全な次元計算
#      14             n_oversamples=10,  # サンプリング数削減
#      15             power_iteration_normalizer="QR",  # 数値安定性向上
#      16             n_iter=2,  # 反復回数削減
#      17         )
#      18     elif algorithm == "arpack":
#      19         (U, S, V) = svds(M, k=min(k, min(M.shape) - 1))
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/extmath.py:446, in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state, svd_lapack_driver)
#     442 if transpose:
#     443     # this implementation is a bit faster with smaller shape[1]
#     444     M = M.T
# --> 446 Q = randomized_range_finder(
#     447     M,
#     448     size=n_random,
#     449     n_iter=n_iter,
#     450     power_iteration_normalizer=power_iteration_normalizer,
#     451     random_state=random_state,
#     452 )
#     454 # project M to the (k + p) dimensional space using the basis vectors
#     455 B = safe_sparse_dot(Q.T, M)
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/extmath.py:278, in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     276     elif power_iteration_normalizer == "QR":
#     277         Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode="economic")
# --> 278         Q, _ = linalg.qr(safe_sparse_dot(A.T, Q), mode="economic")
#     280 # Sample the range of A using by linear projection of Q
#     281 # Extract an orthonormal basis
#     282 Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode="economic")
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/sklearn/utils/extmath.py:192, in safe_sparse_dot(a, b, dense_output)
#     188 else:
#     189     ret = a @ b
#     191 if (
# --> 192     sparse.issparse(a)
#     193     and sparse.issparse(b)
#     194     and dense_output
#     195     and hasattr(ret, "toarray")
#     196 ):
#     197     return ret.toarray()
#     198 return ret
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/scipy/sparse/_base.py:1335, in issparse(x)
#    1329     """A namespace class to separate sparray from spmatrix"""
#    1332 sparray.__doc__ = _spbase.__doc__
# -> 1335 def issparse(x):
#    1336     """Is `x` of a sparse array or sparse matrix type?
#    1337
#    1338     Parameters
#    (...)
#    1359     False
#    1360     """
#    1361     return isinstance(x, _spbase)
#
# KeyboardInterrupt:

# %%
true_data_s.to_csv(f"new_drug_true_{args.data}.csv")
predict_data_s.to_csv(f"new_drug_pred_{args.data}.csv")
# Out:
#              740     752     755     757     762     1390    1895    3053    \
# 786_0             1       1       1       1       1       1       1       1
# A498              0       0       0       1       0       0       1       0
# A549              1       0       0       1       1       0       1       1
# ACHN              1       0       0       0       1       1       1       0
# BT_549            0       0       0       0       0       0       0       0
# CAKI_1            1       1       1       0       1       1       1       0
# CCRF_CEM          1       1       1       1       1       1       1       1
# COLO205           0       0       1       1       0       0       0       1
# DU_145            1       1       1       0       1       1       0       0
# EKVX              0       0       0       0       0       0       1       0
# HCC_2998          1       1       1       1       0       1       0       0
# HCT_116           1       1       1       1       0       0       0       1
# HCT_15            1       1       1       0       1       1       0       0
# HL_60             1       1       1       1       1       1       1       0
# HOP_62            1       1       1       1       0       1       0       0
# HOP_92            0       1       1       1       1       1       0       0
# HS578T            0       0       0       0       0       0       0       0
# HT29              1       1       1       1       0       0       0       1
# IGROV1            1       0       0       1       0       1       0       0
# KM12              1       0       0       1       0       0       0       1
# K_562             1       1       1       1       0       1       0       1
# LOXIMVI           1       1       1       1       1       1       1       1
# M14               1       1       1       1       0       1       1       0
# MALME_3M          0       0       1       1       1       0       0       1
# MCF7              1       1       1       1       1       1       1       1
# MDA_MB_231        0       0       0       0       0       1       0       0
# MDA_MB_435        1       1       1       0       0       1       0       1
# MDA_N             1       1       1       0       0       0       0       1
# MOLT_4            1       1       1       1       1       0       1       1
# NCI_ADR_RES       1       1       1       0       0       1       1       0
# NCI_H226          0       0       0       1       0       0       0       1
# NCI_H23           1       1       1       1       1       1       0       0
# NCI_H322M         0       0       0       1       0       1       0       0
# NCI_H460          1       1       0       1       1       0       1       1
# NCI_H522          1       1       1       1       1       1       1       1
# OVCAR_3           0       1       1       1       0       1       0       0
# OVCAR_4           0       0       0       0       0       1       0       0
# OVCAR_5           0       1       0       0       0       0       0       0
# OVCAR_8           1       1       1       1       0       1       1       1
# PC_3              1       0       1       0       0       1       0       0
# RPMI_8226         1       1       1       1       1       1       0       1
# RXF_393           0       1       0       1       1       1       0       0
